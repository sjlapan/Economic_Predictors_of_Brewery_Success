# %%
import pandas as pd

# %%
income_data_df= pd.read_csv("Resources/16zpallnoagi.csv")

# %%
income_data_df.head()
# Out:
#    STATEFIPS STATE  ZIPCODE  AGI_STUB       N1   MARS1   MARS2   MARS4  \
# 0          1    AL        0         0  2016530  825680  748830  402320
# 1          1    AL    35004         0     5210    2150    2140     830
# 2          1    AL    35005         0     3100    1340     890     830
# 3          1    AL    35006         0     1200     430     600     170
# 4          1    AL    35007         0    11940    4770    5140    1750
#
#       PREP       N2   ...      N10300    A10300  N85530  A85530  N85300  \
# 0  1140180  4065690   ...     1458270  14219765   23560   40254   28280
# 1     2470    10510   ...        4140     28671       0       0      30
# 2     1740     6020   ...        2180      9262       0       0       0
# 3      790     2560   ...         910      4982       0       0       0
# 4     5450    24950   ...        9340     75822      90      79      90
#
#    A85300  N11901   A11901   N11902   A11902
# 0   89091  358370  1683323  1583690  4690385
# ...

# %%
income_data_df.describe()
# Out:
#           STATEFIPS       ZIPCODE  AGI_STUB            N1         MARS1  \
# count  29974.000000  29974.000000   29974.0  2.997400e+04  2.997400e+04
# mean      29.682258  49238.813505       0.0  9.812806e+03  4.642993e+03
# std       15.221184  27533.700223       0.0  1.786246e+05  8.541280e+04
# min        1.000000      0.000000       0.0  4.000000e+01  0.000000e+00
# 25%       18.000000  26541.250000       0.0  4.700000e+02  2.000000e+02
# 50%       29.000000  49046.500000       0.0  1.580000e+03  6.800000e+02
# 75%       42.000000  71752.750000       0.0  6.970000e+03  3.170000e+03
# max       56.000000  99999.000000       0.0  1.753239e+07  8.548260e+06
#
#               MARS2         MARS4          PREP            N2        NUMDEP  \
# count  2.997400e+04  2.997400e+04  2.997400e+04  2.997400e+04  2.997400e+04
# mean   3.552793e+03  1.422555e+03  5.234573e+03  1.897965e+04  6.228723e+03
# std    6.334151e+04  2.702447e+04  1.001974e+05  3.497087e+05  1.187614e+05
# ...

# %%
zips_less_than_100_returns= income_data_df.loc[income_data_df["ZIPCODE"] == 99999]

# %%
saved_columns= {
    "STATEFIPS":"STATE FIPS",
    "STATE":"STATE",
    "ZIPCODE":"ZIPCODE",
    "AGI_STUB":"",
    #TOTAL NUMBER OF RETURNS
    "N1":"NUMBER OF RETURNS",
    #DETERMINE MARITAL STATUS
    "MARS1":"MARITAL STATUS (SINGLE)",
    "MARS2":"MARITAL STATUS (JOINT)",
    "MARS4":"MARITAL STATUS (HEAD OF HOUSEHOLD)",
    #NOT SURE WHY,
    "PREP":"RETURNS WITH SIGNATURE",
    #TOTAL NUMBER OF EXEMPTIONS,
    "N2":"NUMBER OF EXEMPTIONS",
    #DETERMINE FAMILIES
    "NUMDEP":"NUMBER OF DEPENDENTS",
    #DETERMINE AGE DEMOGRAPHICS
    "ELDERLY":"ELDERLY",
    #TOTAL INCOME
    "N02650":"NUMBER OF RETURNS WITH TOTAL INCOME",
    "A02650":"TOTAL INCOME AMOUNT",
    #SALARIES AND WAGES (AVERAGE)
    "N00200":"NUMBER OF RETURNS WITH SALARIES AND WAGES",
    "A00200":"SALARIES AND WAGES AMOUNT",
    #RURAL AREAS
    "SCHF":"NUMBER OF FARM RETURNS",
    #EMPLOYMENT DEMOGRAPHICS
    "N02300":"NUMBER OF RETURNS WITH UNEMPLOYMENT COMPENSATION",
    "A02300":"UNEMPLOYMENT COMPENSATION AMOUNT",
    #AGE DEMOGRAPHICS
    "N02500":"NUMBER OF RETURNS WITH SOCIAL SECURITY BENEFITS",
    "A02500":"TAXABLE SOCIAL SECURITY BENEFITS AMOUNT",
    #COLLEGE TOWNS
    "N03220":"NUMBER OF RETURNS WITH EDUCATION EXPENSES",
    "A03220":"EDUCATION EXPENSES AMOUNT",
    "N03210":"NUMBER OF RETURNS WITH STUDENT LOAN DEDUCTIONS",
    "A03210":"STUDENT LOAN DEDUCTIONS AMOUNT",
    "N03230":"NUMBER OF RETURNS WITH TUITION AND FEEDS DEDUCTIONS",
    "A03230":"TUITION AND FEEDS DEDUCTIONS AMOUNT",
    #MANUFACTURING SECTORS
    "N03240":"NUMBER OF RETURNS WITH DOMESTIC PRODUCTION ACTIVITIES DEDUCTIONS",
    "A03240":"DOMESTIC PRODUCTION ACTIVITES DEDUCTIONS AMOUNT",
    #PROPERTY OWNERS VS RENTERS
    "N18500":"NUMBER OF RETURNS WITH REAL ESTATE TAXES",
    "A18500":"REAL ESTATE TAXES AMOUNT",
    "N18800":"NUMBER OF RETURNS WITH PERSONAL PROPERTY TAXES",
    "A18800":"PERSONAL PROPERTY TAXES AMOUNT",
    #CHARITABLE NEIGHBORHOODS
    "N19700":"NUMBER OF RETURNS WITH TOTAL CHARITABLE CONTRIBUTIONS",
    "A19700":"TOTAL CHARITABLE CONTRIBUTIONS AMOUNT",
    #TAXABLE INCOME
    "N04800":"NUMBER OF RETURNS WITH TAXABLE INCOME",
    "A04800":"TAXABLE INCOME AMOUNT",
    "N05800":"NUMBER OF RETURNS WITH INCOME TAX BEFORE CREDITS",
    "A05800":"INCOME TAX BEFORE CREDITS AMOUNT",
    #TAX CREDITS (DOMESTIC AND FOREIGN)
    "N07100":"NUMBER OF RETURNS WITH TOTAL TAX CREDITS",
    "A07100":"TOTAL TAX CREDITS AMOUNT",
    "N07300":"NUMBER OF RETURNS WITH FOREIGN TAX CREDIT",
    "A07300":"FOREIGN TAX CREDIT AMOUNT",
    #CHILDCARE TAX CREDITS
    "N07180":"NUMBER OF RETURNS WITH CHILD AND DEPENDENT CARE CREDIT",
    "A07180":"CHILD AND DEPENDENT CARE CREDIT AMOUNT",
    "N09400":"NUMBER OF RETURNS WITH SELF-EMPLOYMENT TAX",
    "A09400":"SELF-EMPLOYMENT TAX AMOUNT",
    "N06500":"NUMBER OF RETURNS WITH INCOME TAX",
    "A06500":"INCOME TAX AMOUNT"
}

# %%
income_data_df_saved_columns= income_data_df.loc[:,saved_columns.keys()]
income_data_df_saved_columns.rename(columns= saved_columns, inplace= True)

# %%
income_data_df_saved_columns.head()
# Out:
#    STATE FIPS STATE  ZIPCODE     NUMBER OF RETURNS  MARITAL STATUS (SINGLE)  \
# 0           1    AL        0  0            2016530                   825680
# 1           1    AL    35004  0               5210                     2150
# 2           1    AL    35005  0               3100                     1340
# 3           1    AL    35006  0               1200                      430
# 4           1    AL    35007  0              11940                     4770
#
#    MARITAL STATUS (JOINT)  MARITAL STATUS (HEAD OF HOUSEHOLD)  \
# 0                  748830                              402320
# 1                    2140                                 830
# 2                     890                                 830
# 3                     600                                 170
# 4                    5140                                1750
#
#    RETURNS WITH SIGNATURE  NUMBER OF EXEMPTIONS        ...          \
# 0                 1140180               4065690        ...
# ...

# %%
incomes= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH TOTAL INCOME",
                                             "TOTAL INCOME AMOUNT"
                                            ]]
incomes.loc[(incomes['ZIPCODE'] != 0) & (incomes['ZIPCODE'] != 99999)]\
    .sort_values("TOTAL INCOME AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  NUMBER OF RETURNS WITH TOTAL INCOME  \
# 17126    NY    10023              34070                                34070
# 2573     CA    94301               8510                                 8510
# 17124    NY    10021              23530                                23530
# 17149    NY    10128              32950                                32950
# 17127    NY    10024              30410                                30410
# 17125    NY    10022              19840                                19840
# 17131    NY    10028              25100                                25100
# 17116    NY    10011              29920                                29920
# 6349     IL    60614              35330                                35330
# 17243    NY    10583              18730                                18730
#
#        TOTAL INCOME AMOUNT
# 17126             11936570
# 2573              10936666
# 17124             10700368
# ...

# %%
salaries_and_wages= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH SALARIES AND WAGES",
                                             "SALARIES AND WAGES AMOUNT"
                                            ]]
salaries_and_wages.loc[(salaries_and_wages['ZIPCODE'] != 0) & (salaries_and_wages['ZIPCODE'] != 99999)]\
    .sort_values("SALARIES AND WAGES AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 17126    NY    10023              34070
# 17149    NY    10128              32950
# 17127    NY    10024              30410
# 17116    NY    10011              29920
# 25825    TX    77494              41890
# 17124    NY    10021              23530
# 17128    NY    10025              45610
# 6349     IL    60614              35330
# 17350    NY    11201              31970
# 17131    NY    10028              25100
#
#        NUMBER OF RETURNS WITH SALARIES AND WAGES  SALARIES AND WAGES AMOUNT
# 17126                                      25810                    5856720
# 17149                                      26220                    5173731
# 17127                                      23270                    5145394
# 17116                                      24190                    4685867
# 25825                                      37520                    4603255
# ...

# %%
farms= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF FARM RETURNS"
                                            ]]
farms.loc[(farms['ZIPCODE'] != 0) & (farms['ZIPCODE'] != 99999)]\
    .sort_values("NUMBER OF FARM RETURNS", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  NUMBER OF FARM RETURNS
# 26254    TX    78624              11090                    1350
# 25926    TX    77833              11750                    1160
# 10041    KY    42141              12790                    1140
# 25429    TX    76401              10750                    1010
# 26054    TX    78155              21480                     970
# 25956    TX    77964               3570                     940
# 25380    TX    76234               7760                     860
# 10177    KY    42728               5980                     830
# 25928    TX    77836               5040                     820
# 20457    OH    44654               8750                     810

# %%
unemployment= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH UNEMPLOYMENT COMPENSATION",
                                             "UNEMPLOYMENT COMPENSATION AMOUNT"
                                            ]]
unemployment.loc[(unemployment['ZIPCODE'] != 0) & (unemployment['ZIPCODE'] != 99999)]\
    .sort_values("UNEMPLOYMENT COMPENSATION AMOUNT", ascending= False)\
    .head(10)
# Out:
#      STATE  ZIPCODE  NUMBER OF RETURNS  \
# 2043    CA    92231              25020
# 896     AZ    85349              19490
# 2760    CA    95076              36830
# 2490    CA    93905              27550
# 2298    CA    93215              17610
# 2326    CA    93257              27180
# 2349    CA    93307              29400
# 2794    CA    95206              26600
# 2447    CA    93640               5430
# 2491    CA    93906              26530
#
#       NUMBER OF RETURNS WITH UNEMPLOYMENT COMPENSATION  \
# 2043                                              8290
# 896                                               7880
# 2760                                              5970
# 2490                                              5630
# 2298                                              5970
# 2326                                              4380
# 2349                                              4260
# 2794                                              3760
# ...

# %%
education= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH EDUCATION EXPENSES",
                                             "EDUCATION EXPENSES AMOUNT",
                                             "NUMBER OF RETURNS WITH STUDENT LOAN DEDUCTIONS",
                                             "STUDENT LOAN DEDUCTIONS AMOUNT",
                                             "NUMBER OF RETURNS WITH TUITION AND FEEDS DEDUCTIONS",
                                             "TUITION AND FEEDS DEDUCTIONS AMOUNT"
                                            ]]
education.loc[(education['ZIPCODE'] != 0) & (education['ZIPCODE'] != 99999)]\
    .sort_values("STUDENT LOAN DEDUCTIONS AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 6388     IL    60657              39860
# 6380     IL    60647              43770
# 11855    MA     2135              23160
# 6373     IL    60640              34950
# 6353     IL    60618              44110
# 6348     IL    60613              28830
# 4059     DC    20002              34320
# 6349     IL    60614              35330
# 20262    OH    44107              27600
# 6357     IL    60622              28810
#
#        NUMBER OF RETURNS WITH EDUCATION EXPENSES  EDUCATION EXPENSES AMOUNT  \
# 6388                                         960                        230
# 6380                                        1210                        294
# 11855                                        700                        161
# 6373                                         910                        219
# 6353                                        1290                        321
# ...

# %%
manufacturing= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH DOMESTIC PRODUCTION ACTIVITIES DEDUCTIONS",
                                             "DOMESTIC PRODUCTION ACTIVITES DEDUCTIONS AMOUNT"
                                            ]]
manufacturing.loc[(manufacturing['ZIPCODE'] != 0) & (manufacturing['ZIPCODE'] != 99999)]\
    .sort_values("DOMESTIC PRODUCTION ACTIVITES DEDUCTIONS AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 4648     FL    33480               5200
# 4860     FL    34102               4870
# 6086     IL    60035              15080
# 17337    NY    11024               3160
# 25636    TX    77024              15460
# 6069     IL    60010              21650
# 108      AL    35223               5480
# 12212    MI    48304               8590
# 6123     IL    60093               9640
# 839      AZ    85253               8080
#
#        NUMBER OF RETURNS WITH DOMESTIC PRODUCTION ACTIVITIES DEDUCTIONS  \
# 4648                                                 210
# 4860                                                 180
# 6086                                                 300
# 17337                                                 40
# 25636                                                300
# 6069                                                 450
# 108                                                  170
# ...

# %%
real_estate_and_property= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH REAL ESTATE TAXES",
                                             "REAL ESTATE TAXES AMOUNT",
                                             "NUMBER OF RETURNS WITH PERSONAL PROPERTY TAXES",
                                             "PERSONAL PROPERTY TAXES AMOUNT"
                                            ]]
real_estate_and_property.loc[(real_estate_and_property['ZIPCODE'] != 0) & (real_estate_and_property['ZIPCODE'] != 99999)]\
    .sort_values("NUMBER OF RETURNS WITH PERSONAL PROPERTY TAXES", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 3318     CO    80134              32050
# 3011     CA    95630              31900
# 3079     CA    95747              29580
# 19215    NC    28277              31570
# 27226    VA    22193              38230
# 2097     CA    92336              41540
# 1890     CA    91709              34800
# 14309    MO    63376              38810
# 2174     CA    92592              32590
# 27169    VA    20147              29580
#
#        NUMBER OF RETURNS WITH REAL ESTATE TAXES  REAL ESTATE TAXES AMOUNT  \
# 3318                                      16110                     54812
# 3011                                      15220                     83812
# 3079                                      15080                     82467
# 19215                                     15130                     71631
# 27226                                     14740                     57195
# ...

# %%
charity= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH TOTAL CHARITABLE CONTRIBUTIONS",
                                             "TOTAL CHARITABLE CONTRIBUTIONS AMOUNT"
                                            ]]
charity.loc[(charity['ZIPCODE'] != 0) & (charity['ZIPCODE'] != 99999)]\
    .sort_values("TOTAL CHARITABLE CONTRIBUTIONS AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 2574     CA    94303              22000
# 1543     AR    72712              23050
# 2573     CA    94301               8510
# 17124    NY    10021              23530
# 11839    MA     2116              10860
# 17126    NY    10023              34070
# 4648     FL    33480               5200
# 17127    NY    10024              30410
# 5234     GA    30327              10510
# 17145    NY    10065              15780
#
#        NUMBER OF RETURNS WITH TOTAL CHARITABLE CONTRIBUTIONS  \
# 2574                                                6800
# 1543                                                7240
# 2573                                                4530
# 17124                                              13520
# 11839                                               4530
# 17126                                              19060
# 4648                                                2900
# ...

# %%
taxable_income_and_before_credits= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH TAXABLE INCOME",
                                             "TAXABLE INCOME AMOUNT",
                                             "NUMBER OF RETURNS WITH INCOME TAX BEFORE CREDITS",
                                             "INCOME TAX BEFORE CREDITS AMOUNT"
                                            ]]
taxable_income_and_before_credits.loc[(taxable_income_and_before_credits['ZIPCODE'] != 0) & (taxable_income_and_before_credits['ZIPCODE'] != 99999)]\
    .sort_values("TAXABLE INCOME AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 17126    NY    10023              34070
# 17149    NY    10128              32950
# 17124    NY    10021              23530
# 17127    NY    10024              30410
# 2573     CA    94301               8510
# 17131    NY    10028              25100
# 17125    NY    10022              19840
# 6349     IL    60614              35330
# 17243    NY    10583              18730
# 17116    NY    10011              29920
#
#        NUMBER OF RETURNS WITH TAXABLE INCOME  TAXABLE INCOME AMOUNT  \
# 17126                                  30410                9351020
# 17149                                  29480                8130001
# 17124                                  21320                8118289
# 17127                                  26980                7926540
# 2573                                    7650                7279755
# 17131                                  22840                7240040
# ...

# %%
childcare= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH CHILD AND DEPENDENT CARE CREDIT",
                                             "CHILD AND DEPENDENT CARE CREDIT AMOUNT"
                                            ]]
childcare.loc[(childcare['ZIPCODE'] != 0) & (childcare['ZIPCODE'] != 99999)]\
    .sort_values("CHILD AND DEPENDENT CARE CREDIT AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 25825    TX    77494              41890
# 17383    NY    11236              47920
# 24928    TX    75070              44100
# 25874    TX    77584              36020
# 25780    TX    77433              36050
# 25792    TX    77449              50660
# 25867    TX    77573              37700
# 17381    NY    11234              42560
# 4476     FL    33025              33720
# 26280    TX    78660              42100
#
#        NUMBER OF RETURNS WITH CHILD AND DEPENDENT CARE CREDIT  \
# 25825                                               4130
# 17383                                               3650
# 24928                                               3820
# 25874                                               3550
# 25780                                               3570
# 25792                                               3310
# 25867                                               3200
# ...

# %%
self_employed= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH SELF-EMPLOYMENT TAX",
                                             "SELF-EMPLOYMENT TAX AMOUNT"
                                            ]]
self_employed.loc[(self_employed['ZIPCODE'] != 0) & (self_employed['ZIPCODE'] != 99999)]\
    .sort_values("SELF-EMPLOYMENT TAX AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  \
# 17127    NY    10024              30410
# 17149    NY    10128              32950
# 17126    NY    10023              34070
# 17128    NY    10025              45610
# 11204    MD    20854              22620
# 17131    NY    10028              25100
# 17243    NY    10583              18730
# 17116    NY    10011              29920
# 17124    NY    10021              23530
# 24295    TN    37027              26890
#
#        NUMBER OF RETURNS WITH SELF-EMPLOYMENT TAX  SELF-EMPLOYMENT TAX AMOUNT
# 17127                                        7190                       77944
# 17149                                        6420                       71037
# 17126                                        7170                       70345
# 17128                                        9590                       60120
# 11204                                        5470                       59410
# ...

# %%
income_tax= income_data_df_saved_columns.loc[:,["STATE",
                                             "ZIPCODE",
                                             "NUMBER OF RETURNS",
                                             "NUMBER OF RETURNS WITH INCOME TAX",
                                             "INCOME TAX AMOUNT"
                                            ]]
income_tax.loc[(income_tax['ZIPCODE'] != 0) & (income_tax['ZIPCODE'] != 99999)]\
    .sort_values("INCOME TAX AMOUNT", ascending= False)\
    .head(10)
# Out:
#       STATE  ZIPCODE  NUMBER OF RETURNS  NUMBER OF RETURNS WITH INCOME TAX  \
# 17126    NY    10023              34070                              29200
# 17124    NY    10021              23530                              20610
# 17149    NY    10128              32950                              28420
# 17127    NY    10024              30410                              25830
# 2573     CA    94301               8510                               7320
# 17131    NY    10028              25100                              22070
# 17243    NY    10583              18730                              15470
# 17125    NY    10022              19840                              17310
# 17116    NY    10011              29920                              26040
# 2574     CA    94303              22000                              16120
#
#        INCOME TAX AMOUNT
# 17126            2747241
# 17124            2465240
# 17149            2394088
# 17127            2330214
# ...

# %%
tax_df_for_merge_selectcols= income_data_df_saved_columns.loc[
    :,
    ["STATE",
     "ZIPCODE",
     "NUMBER OF RETURNS",
     "NUMBER OF RETURNS WITH TOTAL INCOME",
     "TOTAL INCOME AMOUNT",
     "NUMBER OF RETURNS WITH SALARIES AND WAGES",
     "SALARIES AND WAGES AMOUNT"
    ]]

tax_df_for_merge_selectcols= tax_df_for_merge_selectcols.loc[
     (tax_df_for_merge_selectcols['ZIPCODE'] != 0) & 
     (tax_df_for_merge_selectcols['ZIPCODE'] != 99999)
    ]

tax_df_for_merge_selectcols.to_csv("Resources/Tax_DF_Select_Columns_For_Merge.csv")
tax_df_for_merge_selectcols.head()
# Out:
#   STATE  ZIPCODE  NUMBER OF RETURNS  NUMBER OF RETURNS WITH TOTAL INCOME  \
# 1    AL    35004               5210                                 5210
# 2    AL    35005               3100                                 3100
# 3    AL    35006               1200                                 1200
# 4    AL    35007              11940                                11940
# 5    AL    35010               7910                                 7910
#
#    TOTAL INCOME AMOUNT  NUMBER OF RETURNS WITH SALARIES AND WAGES  \
# 1               290260                                       4550
# 2               121690                                       2660
# 3                57418                                       1040
# 4               697882                                      10180
# 5               384319                                       6700
#
#    SALARIES AND WAGES AMOUNT
# 1                     234833
# 2                      98565
# 3                      43707
# ...

# %%
tax_df_for_merge_allcols= income_data_df_saved_columns.loc[
     (income_data_df_saved_columns['ZIPCODE'] != 0) & 
     (income_data_df_saved_columns['ZIPCODE'] != 99999)
    ]

tax_df_for_merge_allcols.to_csv("Resources/Tax_DF_All_Columns_For_Merge.csv")
tax_df_for_merge_allcols.head()
# Out:
#    STATE FIPS STATE  ZIPCODE     NUMBER OF RETURNS  MARITAL STATUS (SINGLE)  \
# 1           1    AL    35004  0               5210                     2150
# 2           1    AL    35005  0               3100                     1340
# 3           1    AL    35006  0               1200                      430
# 4           1    AL    35007  0              11940                     4770
# 5           1    AL    35010  0               7910                     2910
#
#    MARITAL STATUS (JOINT)  MARITAL STATUS (HEAD OF HOUSEHOLD)  \
# 1                    2140                                 830
# 2                     890                                 830
# 3                     600                                 170
# 4                    5140                                1750
# 5                    2730                                2120
#
#    RETURNS WITH SIGNATURE  NUMBER OF EXEMPTIONS        ...          \
# 1                    2470                 10510        ...
# ...

# %%
zipcodes= ['12345-2345','23456-3456','34567']
test= pd.Series(zipcodes)

test.str.split("-")
test= test.str.split("-").str[0]

test
# Out:
# 0    12345
# 1    23456
# 2    34567
# dtype: object
